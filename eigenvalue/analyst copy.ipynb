# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfs = [
    pd.read_csv('./1.csv'),
    pd.read_csv('./2.csv'),
    pd.read_csv('./3.csv'),
    pd.read_csv('./4.csv'),
    pd.read_csv('./5.csv'),
    pd.read_csv('./6.csv'),
    pd.read_csv('./7.csv'),
]

# %%
means_cpu = []
means_gpu = []

for i in dfs:
    means_cpu.append(i['CPU'].mean())
    means_gpu.append(i['GPU'].mean())

# %%
means_cpu
# Out:
# [1.6699299999999998e-05,
#  0.0001356064,
#  0.0023815273,
#  0.0065705061999999995,
#  0.040864289600000006,
#  2.8235273936,
#  210.2052650053]

# %%
means_gpu
# Out:
# [0.000250931199,
#  0.00039810559400000006,
#  0.000571142396,
#  0.0143110976,
#  0.0345306187,
#  1.0687474329999997,
#  10.71118205]

# %%
TITLE = 'Operasi Inverse Matriks'
fig, axes = plt.subplots(figsize=(12, 8))

width = 0.40
x = np.arange(7)

axes.bar(x-width/2, means_cpu, width=width, label="CPU")
axes.bar(x+width/2, means_gpu, width=width, label="GPU")

axes.set_xticks(x, ['10x10', '50x50', r'$10^2$x$10^2$', '500x500', '$10^3$x$10^3$', '5000x5000', '$10^4$x$10^4$']) 
axes.set_xlabel("Ukuran") 
axes.set_ylabel("Waktu (Detik)")
axes.set_title(TITLE)
axes.set_yscale('log')

axes.legend()
axes.grid()
# fig.tight_layout()
