# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfs = [
    pd.read_csv('./1.csv'),
    pd.read_csv('./2.csv'),
    pd.read_csv('./3.csv'),
    pd.read_csv('./4.csv'),
    pd.read_csv('./5.csv'),
    pd.read_csv('./6.csv'),
    pd.read_csv('./7.csv'),
]

# %%
means_cpu = []
means_gpu = []

for i in dfs:
    means_cpu.append(i['CPU'].mean())
    means_gpu.append(i['GPU'].mean())

# %%
means_cpu
# Out:
# [1.4290099999999999e-05,
#  0.0001356064,
#  0.0023815273,
#  0.0134418544,
#  0.03808624,
#  2.8235273936,
#  210.2052650053]

# %%
means_gpu
# Out:
# [0.00019739519900000002,
#  0.00039810559400000006,
#  0.000571142396,
#  0.017912175500000002,
#  0.034511714500000006,
#  1.0687474329999997,
#  10.71118205]

# %%
df_mean = pd.DataFrame()
df_mean['means_cpu'] = means_cpu
df_mean['means_gpu'] = means_gpu
df_mean
# Out:
#     means_cpu  means_gpu
# 0    0.000014   0.000197
# 1    0.000136   0.000398
# 2    0.002382   0.000571
# 3    0.013442   0.017912
# 4    0.038086   0.034512
# 5    2.823527   1.068747
# 6  210.205265  10.711182

# %%
TITLE = 'Operasi Inverse Matriks'
fig, axes = plt.subplots(figsize=(12, 8))

width = 0.40
x = np.arange(7)

axes.bar(x-width/2, means_cpu, width=width, label="CPU")
axes.bar(x+width/2, means_gpu, width=width, label="GPU")

axes.set_xticks(x, ['10x10', '50x50', r'$10^2$x$10^2$', '500x500', '$10^3$x$10^3$', '5000x5000', '$10^4$x$10^4$']) 
axes.set_xlabel("Ukuran") 
axes.set_ylabel("Waktu (Detik)")
axes.set_title(TITLE)
axes.set_yscale('log')

axes.legend()
axes.grid()
# fig.tight_layout()
