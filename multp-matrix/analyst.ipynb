# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfs = [
    pd.read_csv('./1.csv'),
    pd.read_csv('./2.csv'),
    pd.read_csv('./3.csv'),
    pd.read_csv('./4.csv'),
    pd.read_csv('./5.csv'),
    pd.read_csv('./6.csv'),
    pd.read_csv('./7.csv'),
]

# %%
means_cpu = []
means_gpu = []

for i in dfs:
    means_cpu.append(i['CPU'].mean())
    means_gpu.append(i['GPU'].mean())

# %%
means_cpu
# Out:
# [2.1719e-06,
#  2.88459e-05,
#  0.0004589816,
#  0.0032832403999999995,
#  0.017756165900000002,
#  1.2315838221,
#  25.7547176659]

# %%
means_gpu
# Out:
# [6.03936007e-05,
#  9.7187198e-05,
#  9.811519970000002e-05,
#  0.0004160896,
#  0.003404857520000001,
#  0.29779716700000003,
#  2.2115181899999996]

# %%
df_mean = pd.DataFrame()
df_mean['means_cpu'] = means_cpu
df_mean['means_gpu'] = means_gpu
df_mean
# Out:
#    means_cpu  means_gpu
# 0   0.000002   0.000060
# 1   0.000029   0.000097
# 2   0.000459   0.000098
# 3   0.003283   0.000416
# 4   0.017756   0.003405
# 5   1.231584   0.297797
# 6  25.754718   2.211518

# %%
TITLE = 'Operasi Perkalian Matriks'
fig, axes = plt.subplots(figsize=(12, 8))

width = 0.40
x = np.arange(7)

axes.bar(x-width/2, means_cpu, width=width, label="CPU")
axes.bar(x+width/2, means_gpu, width=width, label="GPU")

axes.set_xticks(x, ['10x10', '50x50', r'$10^2$x$10^2$', '500x500', '$10^3$x$10^3$', '5000x5000', '$10^4$x$10^4$']) 
axes.set_xlabel("Ukuran") 
axes.set_ylabel("Waktu (Detik)")
axes.set_title(TITLE)
axes.set_yscale('log')

axes.legend()
axes.grid()
# fig.tight_layout()
