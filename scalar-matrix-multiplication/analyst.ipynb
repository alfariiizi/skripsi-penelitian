# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfs = [
    pd.read_csv('./1.csv'),
    pd.read_csv('./2.csv'),
    pd.read_csv('./3.csv'),
    pd.read_csv('./4.csv'),
    pd.read_csv('./5.csv'),
    pd.read_csv('./6.csv'),
    pd.read_csv('./7.csv'),
]

# %%
means_cpu = []
means_gpu = []

for i in dfs:
    means_cpu.append(i['CPU'].mean())
    means_gpu.append(i['GPU'].mean())

# %%
means_cpu
# Out:
# [1.0655e-06,
#  1.5514900000000003e-05,
#  3.4273700000000004e-05,
#  0.0009130456999999999,
#  0.0029308645,
#  0.28625631339999996,
#  0.4188525466]

# %%
means_gpu
# Out:
# [3.55359995e-05,
#  7.137279939999999e-05,
#  3.1763200299999996e-05,
#  0.00014078079900000002,
#  0.000456108811,
#  0.0078736321,
#  0.031236377800000003]

# %%
df_mean = pd.DataFrame()
df_mean['means_cpu'] = means_cpu
df_mean['means_gpu'] = means_gpu
df_mean
# Out:
#    means_cpu  means_gpu
# 0   0.000001   0.000036
# 1   0.000016   0.000071
# 2   0.000034   0.000032
# 3   0.000913   0.000141
# 4   0.002931   0.000456
# 5   0.286256   0.007874
# 6   0.418853   0.031236

# %%
TITLE = 'Operasi Perkalian Skalar dengan Matriks'
fig, axes = plt.subplots(figsize=(12, 8))

width = 0.40
x = np.arange(7)

axes.bar(x-width/2, means_cpu, width=width, label="CPU")
axes.bar(x+width/2, means_gpu, width=width, label="GPU")

axes.set_xticks(x, ['10x10', '50x50', r'$10^2$x$10^2$', '500x500', '$10^3$x$10^3$', '5000x5000', '$10^4$x$10^4$']) 
axes.set_xlabel("Ukuran") 
axes.set_ylabel("Waktu (Detik)")
axes.set_title(TITLE)
axes.set_yscale('log')

axes.legend()
axes.grid()
# fig.tight_layout()
